# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
data = np.load("results\Full_Dataset_June_21-UCOnly-SiOnly-_CoordsSet\out.npy")

# %%
data.shape
# Out:
# (20697, 384, 4)

# %%
data[0,:,:]
# Out:
# array([[ 0.00292638, -0.00921659,  0.00196848, -0.00109552],
#        [ 0.0112598 ,  0.00217262,  0.00967962, -0.00364434],
#        [ 0.0041687 , -0.00257591, -0.00202822,  0.00355099],
#        ...,
#        [ 0.00319443, -0.00722729, -0.00617257, -0.00162488],
#        [ 0.00440155, -0.00720116, -0.00144787,  0.00278968],
#        [ 0.3369524 ,  0.17892772,  0.73285604,  1.0159298 ]],
#       dtype=float32)

# %%
index = 2


fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

x = data[index, :, 0]
y = data[index, :, 1]
z = data[index, :, 2]
# c = data[:, 3]

    # colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

ax.scatter(x, y, z)
plt.show()

# %%
index = 1

plot = data[index,:,:]

to_plot = np.zeros((1,4))

for i in range(0,plot.shape[0]):
    if plot[i,3] > 0.5:
        to_plot = np.append(to_plot,np.expand_dims(plot[i,:],axis=0),axis = 0)
to_plot = to_plot[1:,:]


fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

x = to_plot[:, 0]
y = to_plot[:, 1]
z = to_plot[:, 2]
# c = data[:, 3]

    # colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

ax.scatter(x, y, z)
plt.show()

# %%
f = h5py.File('data/Structures-tar-Sionly-frac.h5', 'r')

# %%
for i in f:
    data = (f[i]["test"][...])

# %%
index = 0

plot = data[index,:,:]

to_plot = np.zeros((1,4))

for i in range(0,plot.shape[0]):
    if plot[i,3] > 0.5:
        to_plot = np.append(to_plot,np.expand_dims(plot[i,:],axis=0),axis = 0)
to_plot = to_plot[1:,:]


fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

x = to_plot[:, 0]
y = to_plot[:, 1]
z = to_plot[:, 2]
# c = data[:, 3]

    # colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

ax.scatter(x, y, z)
plt.show()
